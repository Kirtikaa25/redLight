# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirtikaa25/redLight/blob/main/Apriori3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mlxtend pandas
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.11/dist-packages (0.23.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# 🟩 STEP 3: Load and Clean the Dataset

# Load CSV file
df = pd.read_csv('/content/red light violation.csv')

# Clean up messy column names: remove leading/trailing spaces and line breaks
df.columns = df.columns.str.strip().str.replace('\n', ' ', regex=True)

# 🔁 Remove exact duplicate columns (if any)
df = df.loc[:, ~df.columns.duplicated()]

# 🔍 Remove columns with suffixes like .1, .2 (often duplicates from Excel or form exports)
df = df.loc[:, ~df.columns.str.contains(r'\.\d+$')]

# Drop unwanted columns (only if they still exist)
columns_to_drop = [
    'Name', 'Email', 'Timestamp',
    'n which areas do you think red light violations are more of a problem ?',
    'Do you believe that adding countdown timers to traffic lights would reduce red light violations?',
    'What strategies or policies might make you less likely to run a red light ?',
    'In which areas do you think red light violations are more of a problem ?',
    'What strategies or policies might make you less likely to run a red light , and which measures do you think would most effectively reduce red light running?',
    'What type of public awareness campaign would be most likely to influence your driving behaviour regarding red light running ?',
    ''
]

# Only drop columns if they exist
df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# Optional: Print remaining column names for inspection
print("Remaining columns:", df.columns.tolist())

# Preview cleaned dataframe
df.head()
# Out:
# Remaining columns: ['Age Group', 'Gender', 'Occupation', 'Approximate monthly income of the person who violates traffic signals', 'Education level', 'Driving Experience', 'How often do your friends describe you as argumentative?', 'Do you openly express disagreement with your friends?', 'Do you find yourself getting into arguments when people disagree with you?', 'Do you get into physical fights more frequently than the average person?', 'Have you ever been so angry that you broke something?', 'Have you ever crossed the street during a red light?', 'How do you react when you see someone running a red light?', 'How many hours a day do you usually drive?', 'What are the main reasons that make you more likely to cross during a red light?', 'How often do you cross during a red light ?', 'Do you believe that adding countdown timers effect on red light violation?', 'When do you believe red light violations are most common?', 'Which type of vehicle is more likely to violate red light?', 'Which type of intersections do you believe is most prone to red light violations?']
#   Age Group Gender Occupation  \
# 0   19 - 29   Male   Employed
# 1   19 - 29   Male    Student
# 2   19 - 29   Male    Student
# 3   19 - 29   Male    Student
# 4   19 - 29   Male    Student
#
#   Approximate monthly income of the person who violates traffic signals  \
# 0                                           20k -50k
# 1                                     Less than 20 k
# 2                                     Less than 20 k
# 3                                           20k -50k
# 4                                       50k - 1 lakh
#
#               Education level Driving Experience  \
# 0  Post -Graduation and above  More than 5 years
# 1                  Graduation          0 -1 year
# 2                  Graduation                NaN
# 3                  Graduation  More than 5 years
# 4                  Graduation         1- 5 years
#
#   How often do your friends describe you as argumentative?  \
# 0                                           Moderate
# 1                                           Moderate
# 2                                           Moderate
# 3                                           Moderate
# 4                                           Moderate
#
#   Do you openly express disagreement with your friends?  \
# 0                                           Somewhat
# 1                                           Somewhat
# 2                                           Somewhat
# 3                                           Somewhat
# 4                                           Somewhat
#
#   Do you find yourself getting into arguments when people disagree with you?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                          Sometimes
# 4                                          Sometimes
#
#   Do you get into physical fights more frequently than the average person?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Have you ever been so angry that you broke something?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Have you ever crossed the street during a red light?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   How do you react when you see someone running a red light?  \
# 0                                    Feel frustrated
# 1                                                NaN
# 2                                                NaN
# 3                                    Feel frustrated
# 4                                                NaN
#
#   How many hours a day do you usually drive?  \
# 0                                 1 -3 hours
# 1                                        NaN
# 2                                        NaN
# 3                           Less then 1 hour
# 4                                        NaN
#
#   What are the main reasons that make you more likely to cross during a red light?  \
# 0                   To save time or avoid long waits
# 1                                                NaN
# 2                                                NaN
# 3                   To save time or avoid long waits
# 4                                                NaN
#
#   How often do you cross during a red light ?  \
# 0                                         NaN
# 1                   Only in case of emergency
# 2                   Only in case of emergency
# 3                                         NaN
# 4                   Only in case of emergency
#
#   Do you believe that adding countdown timers effect on red light violation?  \
# 0                                                NaN
# 1                             Yes ,but only slightly
# 2                             Yes ,but only slightly
# 3                                                NaN
# 4                            Yes,it would help a lot
#
#   When do you believe red light violations are most common?  \
# 0                                                NaN
# 1                 Weekdays during peak traffic hours
# 2                 Weekdays during peak traffic hours
# 3      Weekdays during non -peak or late night hours
# 4                 Weekdays during peak traffic hours
#
#   Which type of vehicle is more likely to violate red light?  \
# 0                                                NaN
# 1                                      Auto rickshaw
# 2                                      Auto rickshaw
# 3                                        Motorcycles
# 4                                        Motorcycles
#
#   Which type of intersections do you believe is most prone to red light violations?
# 0                                                NaN
# 1                                   All of the above
# 2                                   All of the above
# 3                             Circular intersections
# 4                                   All of the above

# %%
# 🟩 STEP 4: Encode Data for Apriori

# Optional but recommended: Drop rows with missing values to avoid issues during encoding
df.dropna(inplace=True)

# Convert each row into a list of strings in the format "column=value"
transactions = df.apply(lambda row: [f"{col}={row[col]}" for col in df.columns], axis=1).tolist()

# Use TransactionEncoder to convert the transactions into a one-hot encoded format
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)

# Create a DataFrame from the encoded array
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# Preview the encoded DataFrame
df_encoded.head()
# Out:
#    Age Group=19 - 29  Age Group=30 - 49  Age Group=Above 50  \
# 0              False              False                True
# 1              False              False                True
# 2              False               True               False
# 3              False               True               False
# 4              False              False                True
#
#    Approximate monthly income of the person who violates traffic signals=20k -50k  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Approximate monthly income of the person who violates traffic signals=50k - 1 lakh  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Approximate monthly income of the person who violates traffic signals=Above 1 lakh  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    Approximate monthly income of the person who violates traffic signals=Less than 20 k  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Approximate monthly income of the person who violates traffic signals=Not like to disclose  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Do you believe that adding countdown timers effect on red light violation?=Negative effect  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Do you believe that adding countdown timers effect on red light violation?=No ,it wouldn't make a difference  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    When do you believe red light violations are most common?=Weekends during non - peak or late night hours  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    When do you believe red light violations are most common?=Weekends during peak traffic hours  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#    Which type of intersections do you believe is most prone to red light violations?=All of the above  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                              False
#
#    Which type of intersections do you believe is most prone to red light violations?=Circular intersections  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Which type of intersections do you believe is most prone to red light violations?=Four signalised intersections  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Which type of intersections do you believe is most prone to red light violations?=Three signalised intersectiions  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Which type of vehicle is more likely to violate red light?=Auto rickshaw  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#    Which type of vehicle is more likely to violate red light?=Cars  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Which type of vehicle is more likely to violate red light?=Heavy vehicles  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Which type of vehicle is more likely to violate red light?=Motorcycles
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
# [5 rows x 71 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Optional: Drop very rare columns (appear in < 1% of transactions)
min_col_support = 0.01
min_count = min_col_support * len(df_encoded)
df_filtered = df_encoded.loc[:, df_encoded.sum() > min_count]

# Apply Apriori algorithm
frequent_itemsets = apriori(
    df_filtered,
    min_support=0.01,
    use_colnames=True,
    max_len=3  # You can change this depending on how deep you want the rules to go
)

# Add a column for 'fatal_occurrences' = actual counts
frequent_itemsets['fatal_occurrences'] = (frequent_itemsets['support'] * len(df_encoded)).astype(int)

# Sort itemsets by occurrence count
frequent_itemsets = frequent_itemsets.sort_values(by='fatal_occurrences', ascending=False)

# Show top itemsets
frequent_itemsets.head()
# Out:
#       support                                           itemsets  \
# 28       0.96                                      (Gender=Male)
# 49       0.84                              (Occupation=Employed)
# 1314     0.82                 (Gender=Male, Occupation=Employed)
# 15       0.76  (Do you get into physical fights more frequent...
# 802      0.74  (Do you get into physical fights more frequent...
#
#       fatal_occurrences
# 28                   48
# 49                   42
# 1314                 41
# 15                   38
# 802                  37

# %%
from mlxtend.frequent_patterns import association_rules

# Generate rules using confidence as the main metric
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Filter rules:
# 1. Lift > 1 → rule is better than random
# 2. Confidence < 1 → avoid rules that are always true (too obvious)
rules = rules[(rules['lift'] > 1) & (rules['confidence'] < 1)]

# Sort by confidence or lift (optional)
rules = rules.sort_values(by='confidence', ascending=False)

# Display top rules
rules.head()
# Out:
#                                           antecedents            consequents  \
# 1                               (Occupation=Employed)          (Gender=Male)
# 2   (Do you get into physical fights more frequent...          (Gender=Male)
# 13                                (Age Group=30 - 49)          (Gender=Male)
# 29  (How often do your friends describe you as arg...          (Gender=Male)
# 40  (Do you get into physical fights more frequent...  (Occupation=Employed)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 1                 0.84                0.96     0.82    0.976190  1.016865
# 2                 0.76                0.96     0.74    0.973684  1.014254
# 13                0.68                0.96     0.66    0.970588  1.011029
# 29                0.60                0.96     0.58    0.966667  1.006944
# 40                0.58                0.84     0.56    0.965517  1.149425
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 1                1.0    0.0136        1.68       0.103659  0.836735
# 2                1.0    0.0104        1.52       0.058559  0.755102
# 13               1.0    0.0072        1.36       0.034091  0.673469
# 29               1.0    0.0040        1.20       0.017241  0.591837
# 40               1.0    0.0728        4.64       0.309524  0.651163
#
#     certainty  kulczynski
# 1    0.404762    0.915179
# 2    0.342105    0.872259
# 13   0.264706    0.829044
# 29   0.166667    0.785417
# 40   0.784483    0.816092

# %%
rules['confidence'].value_counts().sort_index()
# Out:
# confidence
# 0.500000    1506
# 0.501377       1
# 0.501484       1
# 0.501511       1
# 0.501805       1
#             ...
# 0.998165       4
# 0.998291       3
# 0.998294       1
# 0.998302      11
# 0.998382       8
# Name: count, Length: 4674, dtype: int64

# %%
# STEP 7: Format and sort output properly

# Select relevant rule columns
final_rules = rules[['antecedents', 'consequents', 'confidence', 'lift']].copy()

# Combine antecedents and consequents into a single list of attribute names
final_rules['Attributes'] = final_rules.apply(
    lambda x: list(x['antecedents']) + list(x['consequents']),
    axis=1
)

# Define function to count how many rows fully match all items in the rule
def count_fatal_occurrences(attrs, data):
    try:
        return data[list(attrs)].all(axis=1).sum()
    except:
        return 0

# Apply the function
final_rules['Fatal occurrences'] = final_rules['Attributes'].apply(
    lambda attrs: count_fatal_occurrences(attrs, df_encoded)
)

# Format 'Attributes' for readability
final_rules['Attributes'] = final_rules['Attributes'].apply(lambda x: ', '.join(x))

# Final selection of columns
final_rules = final_rules[['Attributes', 'Fatal occurrences', 'confidence', 'lift']]

# Round numerical values
final_rules['confidence'] = final_rules['confidence'].round(2)
final_rules['lift'] = final_rules['lift'].round(2)

# Sort the rules
final_rules = final_rules.sort_values(by=['confidence', 'lift'], ascending=False).reset_index(drop=True)

# Add Rule Number
final_rules.index += 1
final_rules.insert(0, 'Rule No.', final_rules.index)

# Show top rules
final_rules.head(15)
# Out:
# <ipython-input-29-6404203cd9c5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rules['confidence'] = final_rules['confidence'].round(2)
# <ipython-input-29-6404203cd9c5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rules['lift'] = final_rules['lift'].round(2)
#     Rule No.                                         Attributes  \
# 1          1                   Occupation=Employed, Gender=Male
# 2          2  Do you get into physical fights more frequentl...
# 3          3  Do you get into physical fights more frequentl...
# 4          4                     Age Group=30 - 49, Gender=Male
# 5          5  How often do your friends describe you as argu...
# 6          6  Education level=Graduation, Do you get into ph...
# 7          7  Education level=Graduation, Do you get into ph...
# 8          8  Education level=Graduation, Gender=Male, Do yo...
# 9          9  Do you get into physical fights more frequentl...
# 10        10  Do you believe that adding countdown timers ef...
# 11        11  Occupation=Employed, How often do your friends...
# 12        12  Do you openly express disagreement with your f...
# 13        13  Have you ever been so angry that you broke som...
# 14        14  Do you openly express disagreement with your f...
# 15        15  Do you get into physical fights more frequentl...
#
#     Fatal occurrences  confidence  lift
# 1                  41        0.98  1.02
# 2                  28        0.97  1.15
# 3                  37        0.97  1.01
# 4                  33        0.97  1.01
# 5                  29        0.97  1.01
# 6                  22        0.96  1.29
# 7                  22        0.96  1.26
# 8                  22        0.96  1.26
# 9                  22        0.96  1.14
# 10                 27        0.96  1.00
# 11                 25        0.96  1.00
# 12                 20        0.95  1.13
# 13                 19        0.95  1.13
# 14                 19        0.95  1.13
# 15                 15        0.94  1.56
